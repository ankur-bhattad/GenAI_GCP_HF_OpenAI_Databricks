# %%
import vertexai
# Out:
# /usr/local/lib/python3.12/dist-packages/google/cloud/aiplatform/models.py:52: FutureWarning: Support for google-cloud-storage < 3.0.0 will be removed in a future version of google-cloud-aiplatform. Please upgrade to google-cloud-storage >= 3.0.0.
#   from google.cloud.aiplatform.utils import gcs_utils

# %%
from vertexai.generative_models import GenerationConfig, GenerativeModel
import time

# %%
model = GenerativeModel("gemini-2.5-flash")

# %%
def call_gemini(prompt, generation_config=GenerationConfig(temperature=1.0)):
    wait_time = 1
    while True:
        try:
            response = model.generate_content(prompt, generation_config=generation_config).text
            return response
            break  # Exit the loop if successful
        except Exception as e:  # Replace with the actual exception type
            time.sleep(wait_time)
            wait_time *= 2  # Double the wait time

# %%
def send_message_gemini(model, prompt):
    wait_time = 1
    while True:
        try:
            response = model.send_message(prompt).text
            return response
            break  # Exit the loop if successful
        except Exception as e:  # Replace with the actual exception type
            time.sleep(wait_time)
            wait_time *= 2  # Double the wait time

# %%
prompt = "What do you think could be a good name for a flower shop that specializes in selling bouquets of dried flowers more than fresh flowers?"
print(call_gemini(prompt))
# Out:
# That's a great niche! Dried flowers evoke a sense of timelessness, rustic charm, and enduring beauty. Here are some name ideas, categorized by their vibe, to help you find the perfect fit:
#
# **Evocative & Poetic:**
# 1.  **Everbloom / Ever Blooms:** Simple, classic, and directly states the lasting nature.
# 2.  **The Lingering Bloom:** Suggests lasting beauty and memory.
# 3.  **Whispering Petals:** Evokes a gentle, delicate, and timeless feel.
# 4.  **Golden Hour Blooms:** Implies sun-dried, warmth, and a beautiful time of day.
# 5.  **Hearth & Bloom:** Connects dried flowers with home, warmth, and enduring comfort.
# 6.  **Memory Petals:** Highlights the sentimental aspect of dried flowers as keepsakes.
# 7.  **Botanical Echoes:** Suggests the lasting essence of flowers.
# 8.  **Sun-Kissed Stems:** Emphasizes the natural drying process.
# 9.  **The Quiet Bloom:** Implies a subtle, understated beauty.
# 10. **Timeless Twig & Bloom:** A bit more rustic, combining elements.
#
# **Direct & Descriptive (with a twist):**
# 11. **Preserved Petals:** Clear and elegant.
# 12. **The Dried Floral Co.** (or & Co.)**:** Modern, straightforward.
# 13. **Eternal Flora:** Sophisticated and enduring.
# 14. **Heirloom Blooms:** Suggests a treasured, vintage quality.
# 15. **Dried & True:** A playful take on "tried and true," implying reliability and lasting beauty.
# 16. **The Perennial Posy:** "Perennial" implies lasting, "Posy" is a charming word for a small bouquet.
# 17. **Forever Foliage & Bloom:** Broadens it to other dried botanicals.
#
# **Modern & Chic:**
# 18. **Stille Bloom** (German for 'still' or 'quiet' - implies preserved and serene).
# 19. **The Curated Stem:** Suggests artistry and careful selection.
# 20. **Bloom & Bone:** A bit edgy, highlighting the skeletal beauty of dried elements.
# 21. **Botanical Drift:** Suggests natural movement and subtle beauty.
# 22. **Petal & Preserved:** Concise and clear.
#
# **Whimsical & Charming:**
# 23. **Willow & Thyme Blooms:** Specific, natural, and inviting.
# 24. **Fleur de Sol** (French for "flower of the sun" - perfect for dried!).
# 25. **The Dried Daisy Co.** (or insert another specific, charming flower).
# 26. **Everlasting Arrangements:** Straightforward and promising.
#
# **Tips for Choosing:**
# *   **Say it out loud:** Does it roll off the tongue?
# *   **Check availability:** Is the name available as a domain name, social media handle, and business registration?
# *   **Consider your target audience:** Are they rustic, modern, elegant?
# *   **Reflect your brand:** Does the name convey the exact aesthetic and feeling you want for your shop?
#
# Good luck with your new venture!

# %%
prompt = "Suggest a name for a flower shop that sells bouquets of dried flowers"
print(call_gemini(prompt))
# Out:
# Here are some name suggestions for a dried flower shop, categorized by the vibe they evoke:
#
# **Elegant & Timeless:**
#
# 1.  **Aeterna Blooms** (Aeterna is Latin for "eternal")
# 2.  **The Enduring Bloom**
# 3.  **Heirloom Petals**
# 4.  **Preserved Petals Co.**
# 5.  **Timeless Tangle**
# 6.  **Flora Aeterna** (Classic Latin touch)
# 7.  **The Keepsake Bloom**
# 8.  **Stilled Florals**
# 9.  **Memory Bloom**
# 10. **Whisper Petals**
#
# **Rustic & Earthy:**
#
# 11. **Wild & Dried Botanicals**
# 12. **Sundried Stems**
# 13. **Earthy Petal Co.**
# 14. **The Rustic Bloom**
# 15. **Willow & Wisp**
# 16. **Forest Floor Florals**
# 17. **Dryad Blooms** (Dryads are tree nymphs, evoking nature)
# 18. **Harvested Hues**
# 19. **Root & Bloom (Dried)**
# 20. **Dusty Bloom**
#
# **Whimsical & Playful:**
#
# 21. **Ever After Blooms**
# 22. **The Perennial Petal**
# 23. **Bloom & Last**
# 24. **Faded Petal Florals**
# 25. **The Drying Rack**
# 26. **Still Life Flowers**
# 27. **Forever Florals**
# 28. **The Timeless Twig**
# 29. **Petal Preservers**
# 30. **Whispering Meadow**
#
# **Direct & Clear:**
#
# 31. **Dried Blooms Shop**
# 32. **The Dried Flower Co.**
# 33. **Everlasting Bouquets**
# 34. **Preserved Flower Designs**
# 35. **Your Dried Florist**
#
# **Tips for Choosing:**
#
# *   **Say it out loud:** Does it roll off the tongue? Is it easy to remember and pronounce?
# *   **Check availability:** Is the name available as a domain name (.com is ideal) and on social media handles?
# *   **Reflect your style:** Does the name convey the aesthetic and quality of your arrangements?
# *   **Target audience:** Who are you trying to attract? A whimsical name might appeal to a different crowd than an elegant one.
# *   **Longevity:** Will you still love this name in 5-10 years?
#
# Good luck with your flower shop!

# %%
prompt = "Tell me about Earth"
print(call_gemini(prompt))
# Out:
# Earth is a truly remarkable and unique planet, the only known celestial body to harbor life. Here's a rundown of what makes our home special:
#
# **1. Our Cosmic Address:**
#
# *   **Third Planet from the Sun:** Earth orbits the Sun at an average distance of about 150 million kilometers (93 million miles).
# *   **Inner Solar System:** It's one of the four terrestrial (rocky) planets, along with Mercury, Venus, and Mars.
# *   **"Goldilocks Zone":** Earth resides in the habitable zone, meaning its distance from the Sun allows for liquid water to exist on its surface, a crucial ingredient for life as we know it.
#
# **2. Physical Characteristics:**
#
# *   **Size & Shape:** It's the fifth-largest planet in the solar system. While often depicted as a perfect sphere, Earth is actually an **oblate spheroid**, meaning it bulges slightly at the equator due to its rotation.
# *   **Composition:** Primarily rocky, with a metallic core.
#     *   **Crust:** The thin, outermost layer we live on.
#     *   **Mantle:** A thick layer of silicate rock that flows slowly over geological timescales.
#     *   **Outer Core:** A liquid layer of iron and nickel, responsible for Earth's magnetic field.
#     *   **Inner Core:** A solid ball of iron and nickel at the planet's center, incredibly hot.
# *   **Density:** It's the densest planet in the Solar System.
# *   **Magnetic Field (Magnetosphere):** Generated by the molten outer core, this field protects Earth from harmful solar winds and cosmic radiation, making life possible.
#
# **3. Atmosphere:**
#
# *   **Composition:** Roughly 78% Nitrogen, 21% Oxygen, 0.9% Argon, and trace amounts of other gases like Carbon Dioxide, Neon, and Helium.
# *   **Purpose:**
#     *   Provides the oxygen necessary for breathing.
#     *   Traps heat (the greenhouse effect) to maintain a stable temperature.
#     *   Protects the surface from most meteoroids and harmful solar radiation (via the ozone layer).
#     *   Drives weather patterns.
#
# **4. Water: The Blue Planet:**
#
# *   **Abundance:** Approximately 71% of Earth's surface is covered by water, mostly in its vast oceans.
# *   **States:** Water exists in all three states on Earth: liquid (oceans, rivers, lakes), solid (ice caps, glaciers), and gas (water vapor in the atmosphere).
# *   **Hydrological Cycle:** Water continuously moves between these states and locations, driven by solar energy.
# *   **Significance:** Liquid water is paramount for life.
#
# **5. Geology and Dynamics:**
#
# *   **Plate Tectonics:** Earth's crust is broken into several large plates that are constantly moving, colliding, and separating. This process is responsible for:
#     *   **Mountains:** Formed where plates collide.
#     *   **Volcanoes:** Often found at plate boundaries.
#     *   **Earthquakes:** Caused by the sudden release of stress along plate boundaries.
#     *   **Continental Drift:** The slow movement of continents over geological time.
#
# **6. Life:**
#
# *   **Biodiversity:** Earth is home to an incredible array of life forms, from microscopic bacteria to gigantic whales.
# *   **Ecosystems:** These living organisms interact with each other and their environment, forming complex and interconnected ecosystems.
# *   **Evolution:** Life on Earth has evolved over billions of years, adapting to diverse environments.
#
# **7. Earth's Moon:**
#
# *   **Only Natural Satellite:** A relatively large moon for a planet of Earth's size.
# *   **Tidal Forces:** The Moon's gravitational pull causes tides in Earth's oceans.
# *   **Stabilizes Tilt:** It helps stabilize Earth's axial tilt, leading to more stable seasons and climate over long periods.
#
# **8. Our Impact:**
#
# *   **Dominant Species:** Humans have become the dominant species, profoundly impacting the planet's systems.
# *   **Environmental Challenges:** Climate change, deforestation, pollution, and biodiversity loss are significant issues driven by human activity.
# *   **Stewardship:** There's a growing global effort to understand and mitigate these impacts to ensure the planet remains habitable for future generations.
#
# In essence, Earth is a dynamic, living world, perfectly sculpted by its unique conditions to foster and sustain an astonishing variety of life. It's a precious and complex system that we are only beginning to fully understand.

# %%
prompt = "Generate a list of ways that makes Earth unique compared to other planets"
print(call_gemini(prompt))
# Out:
# Earth truly stands out among the planets we've observed, largely due to a remarkable convergence of factors that have made it a cradle for life. Here's a list of ways it's unique:
#
# 1.  **Stable, Abundant Liquid Water on the Surface:** While other celestial bodies have ice or atmospheric water vapor, Earth is the only known planet with vast oceans of *stable liquid water* on its surface for billions of years. This is crucial as water is the universal solvent for life.
#
# 2.  **Plate Tectonics:** Earth is the only known planet with active, large-scale plate tectonics. This process constantly recycles Earth's crust, drives volcanism, mountain building, and helps regulate the planet's temperature and carbon cycle over geological timescales, which is essential for long-term climate stability.
#
# 3.  **Oxygen-Rich Atmosphere (a product of life):** Our atmosphere's high concentration of free oxygen (around 21%) is a direct result of photosynthesis by living organisms (primarily plants and cyanobacteria). Most other planetary atmospheres are dominated by carbon dioxide, hydrogen, or helium, or are extremely thin.
#
# 4.  **A Powerful, Global Magnetic Field (Magnetosphere):** Earth's molten iron core generates a strong magnetic field that extends far into space. This magnetosphere deflects harmful solar wind and cosmic radiation, protecting our atmosphere from being stripped away and allowing complex life to thrive on the surface. Mars, for instance, lost much of its atmosphere after its magnetic field weakened.
#
# 5.  **A Large, Stabilizing Moon:** Earth's relatively large Moon (compared to its planet) plays a crucial role. It stabilizes Earth's axial tilt, preventing extreme wobbles that could cause drastic climate shifts. It also creates tides, which might have been important in the origin of life.
#
# 6.  **Ozone Layer:** A direct consequence of our oxygen-rich atmosphere, the ozone layer in the stratosphere absorbs most of the Sun's harmful ultraviolet (UV) radiation, making the surface habitable for land-based life.
#
# 7.  **The Only Known Planet with Life (especially complex, intelligent life):** So far, Earth is the only place we know of that harbors any form of life, from microbes to complex multicellular organisms, and uniquely, intelligent technological civilization.
#
# 8.  **Active and Continuous Geological Activity:** While other planets show signs of past volcanism (Mars, Venus) or current activity (Jupiter's moon Io), Earth's geological processes (driven by plate tectonics, volcanism, earthquakes) are continuous, widespread, and interact profoundly with its atmosphere and oceans, constantly renewing its surface and supplying essential nutrients.
#
# 9.  **A "Just Right" or "Goldilocks" Location in the Habitable Zone:** Earth orbits the Sun at a distance that allows for liquid water to exist on its surface. It's not too hot (like Venus) causing water to boil away, nor too cold (like Mars) causing it to freeze solid. This precise location is critical.
#
# 10. **Complex, Interacting Biogeochemical Cycles:** Earth boasts intricate cycles involving carbon, nitrogen, phosphorus, and water, which are profoundly influenced by living organisms. These cycles regulate the planet's climate and nutrient availability in ways not observed elsewhere.
#
# These unique characteristics combine to create a dynamic, self-regulating system that has allowed life to not just emerge, but to diversify and thrive over billions of years.

# %%
prompt = "What's the best method of boiling water?"
print(call_gemini(prompt))
# Out:
# There isn't one "best" method for boiling water, as it depends on your needs and resources. Here's a breakdown of different methods and their pros and cons:
#
# **1. Stovetop:**
#
# * **Pros:** Widely available, inexpensive, versatile for different pot sizes.
# * **Cons:** Can take longer to boil, requires constant monitoring, potential for spills.
#
# **2. Electric Kettle:**
#
# * **Pros:** Fast and efficient, automatic shut-off for safety, often features temperature control.
# * **Cons:** Can be expensive, less versatile than a stovetop, limited water capacity.
#
# **3. Microwave:**
#
# * **Pros:** Extremely fast, convenient, can be used for small amounts of water.
# * **Cons:** Not suitable for large quantities, can be uneven heating, potential for splattering.
#
# **4. Camping Stove:**
#
# * **Pros:** Portable and efficient for outdoor use, various fuel options available.
# * **Cons:** Can be expensive, requires fuel source, may be less convenient than other methods.
#
# **5. Solar Water Heater:**
#
# * **Pros:** Environmentally friendly, free energy source, can be used in remote locations.
# * **Cons:** Requires sunlight, can be slow, limited water capacity.
#
# **Choosing the best method for you:**
#
# * **For everyday use:** Stovetop is the most common and versatile option. Electric kettles are great for speed and convenience.
# * **For camping:** Camping stoves are essential for outdoor boiling.
# * **For sustainability:** Solar water heaters are an excellent choice if you have access to sunlight.
#
# **Additional Tips:**
#
# * **Use a lid:** This traps heat and speeds up boiling time.
# * **Don't overfill:** Leave space at the top of the pot to prevent overflow.
# * **Watch the water:** Never leave boiling water unattended.
# * **Turn off the heat:** Once the water boils, remove it from the heat source to prevent overboiling.
#
# Ultimately, the best method for boiling water is the one that works best for your situation and preferences.

# %%
prompt = "Why is the sky blue?"
print(call_gemini(prompt))
# Out:
# The sky appears blue due to a phenomenon called **Rayleigh scattering**.
#
# Here's how it works:
#
# * **Sunlight is made up of all colors of the rainbow.**  These colors have different wavelengths.
# * **When sunlight enters the Earth's atmosphere, it interacts with the tiny molecules of air (like nitrogen and oxygen).**
# * **Shorter wavelengths of light, like blue and violet, are scattered more effectively by these molecules than longer wavelengths, like red and orange.**
# * **This scattered blue light reaches our eyes from all directions, making the sky appear blue.**
#
# **Think of it like this:** imagine shining a flashlight through a dusty room. The dust particles scatter the light, making it appear blue. The air molecules in our atmosphere are like tiny dust particles that scatter the blue light from the sun.
#
# **Why is the sky sometimes other colors?**
#
# * **At sunrise and sunset, the sunlight has to travel through more of the atmosphere.**  This means that most of the blue light is scattered away, leaving the longer wavelengths (red and orange) to reach our eyes. That's why we see beautiful red and orange sunsets.
# * **Clouds are white because they are made up of water droplets.** These droplets are much larger than the air molecules and scatter all wavelengths of light equally, giving the clouds a white appearance.
#
# Let me know if you have any other questions!

# %%
generation_config = GenerationConfig(temperature=1.0)
prompt = "What day is it today?"
print(call_gemini(prompt, generation_config))
# Out:
# I do not have access to real-time information, including the current date. To know what day it is, please check a calendar or your device's clock. 😊

# %%
model_travel = GenerativeModel(
    model_name="gemini-2.5-flash",
    system_instruction=[
        "Hello! You are an AI chatbot for a travel web site.",
        "Your mission is to provide helpful queries for travelers.",
        "Remember that before you answer a question, you must check to see if it complies with your mission.",
        "If not, you can say, Sorry I can't answer that question.",
    ],
)

# %%
chat = model_travel.start_chat()

prompt = "What is the best place for sightseeing in Milan, Italy?"

print(send_message_gemini(chat, prompt))
# Out:
# That's a great question for a travel website chatbot!
#
# The best place for sightseeing in Milan, Italy, is arguably the **Duomo di Milano** (Milan Cathedral). It's one of the largest and most magnificent Gothic cathedrals in the world.
#
# Here's why it's a must-see:
# *   **Stunning Architecture:** The sheer scale and intricate details of its spires, statues, and stained-glass windows are breathtaking.
# *   **Rooftop Views:** You can take an elevator or stairs to the rooftop for incredible panoramic views of Milan, and on a clear day, even the Alps.
# *   **Historical Significance:** It has stood for centuries and is a central part of Milanese history and culture.
# *   **Central Location:** It's located in the very heart of the city, Piazza del Duomo, making it easy to access and a great starting point for exploring other attractions.
#
# While you're there, also consider visiting the Galleria Vittorio Emanuele II (a beautiful shopping arcade) and the Royal Palace of Milan, which are right next to the Duomo.

# %%
prompt = "What's for dinner?"
print(send_message_gemini(chat, prompt))
# Out:
# Sorry, I can't answer that question. I am a travel chatbot, and my purpose is to help with travel planning.
#
# For dinner recommendations, I suggest checking out online restaurant review sites or asking a local for their favorite spots!

# %%
prompt = "I'm a high school student. Recommend me a programming activity to improve my skills."
print(call_gemini(prompt))
# Out:
# That's great! Programming activities are a fantastic way to boost your skills. To recommend something that's perfect for you, tell me a little more about your interests and current programming knowledge.
#
# For example:
#
# * **What programming languages do you know (if any)?**
# * **What are you interested in learning about?** (e.g., web development, game development, data science)
# * **Are you looking for something challenging or more casual?**
# * **Do you prefer working solo or in a team?**
#
# Once I have a better understanding of your background and preferences, I can provide a more tailored recommendation.

# %%
prompt = """I'm a high school student. Which of these activities do you suggest and why:
a) learn Python
b) learn JavaScript
c) learn Fortran
"""

print(call_gemini(prompt))
# Out:
# It's great you're thinking about learning programming!  Choosing the right language depends on your goals and interests. Here's a breakdown of each option and why you might choose them:
#
# **a) Learn Python:**
#
# * **Why:**
#     * **Beginner-friendly:** Python is known for its clear, readable syntax, making it a popular choice for beginners.
#     * **Widely applicable:** Python is used in a vast range of fields like web development, data science, machine learning, and automation.
#     * **Large community & resources:**  Tons of tutorials, documentation, and online communities make learning Python easier.
#     * **In-demand skill:** Python developers are highly sought after in various industries.
#
# * **Best if:** You're interested in exploring different areas of programming, data science, machine learning, or building web applications.
#
# **b) Learn JavaScript:**
#
# * **Why:**
#     * **The language of the web:** JavaScript is essential for interactive web pages, animations, and front-end development.
#     * **Growing in popularity:**  JavaScript's use is extending beyond web development, with frameworks like Node.js enabling server-side development.
#     * **Good for building interactive experiences:**  If you're interested in building web games, web applications, or creating visually appealing websites, JavaScript is a good choice.
#
# * **Best if:** You're interested in web development, front-end programming, or creating interactive user experiences.
#
# **c) Learn Fortran:**
#
# * **Why:**
#     * **Scientific computing powerhouse:** Fortran is still widely used in scientific computing, high-performance computing, and engineering applications.
#     * **Legacy code:**  Many existing scientific software programs are written in Fortran, so learning it can be helpful for working with them.
#     * **Efficient performance:**  Fortran is known for its efficiency and ability to handle complex calculations.
#
# * **Best if:** You're interested in scientific computing, numerical analysis, or working with legacy code in those fields.
#
# **Recommendations:**
#
# * **If you're a complete beginner, Python is a great starting point.** Its ease of use and wide applicability make it a valuable skill to have.
# * **If you're drawn to web development, JavaScript is a must-learn.** It's the core language for modern web experiences.
# * **Fortran is more niche and generally not the best choice for a first language.** Unless you have specific goals in scientific computing, other languages might be more beneficial.
#
# **Don't be afraid to explore!** You can learn multiple languages over time. The important thing is to choose something that excites you and aligns with your interests. Good luck with your programming journey!

# %%
prompt = """Decide whether a Tweet's sentiment is positive, neutral, or negative.

Tweet: I loved the new YouTube video you made!
Sentiment:
"""
print(call_gemini(prompt))
# Out:
# Sentiment: **Positive**

# %%
prompt = """Decide whether a Tweet's sentiment is positive, neutral, or negative.

Tweet: I loved the new YouTube video you made!
Sentiment: positive

Tweet: That was awful. Super boring 😠
Sentiment:
"""
print(call_gemini(prompt))
# Out:
# Sentiment: **negative**

# %%
prompt = """Decide whether a Tweet's sentiment is positive, neutral, or negative.

Tweet: I loved the new YouTube video you made!
Sentiment: positive

Tweet: That was awful. Super boring 😠
Sentiment: negative

Tweet: Something surprised me about this video - it was actually original. It was not the same old recycled stuff that I always see. Watch it - you will not regret it.
Sentiment:
"""
print(call_gemini(prompt))
# Out:
# Sentiment: **positive**
#
# Here's why:
#
# * **"Something surprised me about this video - it was actually original."**  This implies a positive experience.
# * **"It was not the same old recycled stuff that I always see."** This is a clear statement of preference for something new and different.
# * **"Watch it - you will not regret it."** This is a strong recommendation, indicating a positive overall sentiment.
